# %% [markdown]
# ## Delaing with ncert book
#
# * pypdf loader

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
# ncert book
ncert_book_path = "data/science-chapter-11.pdf"

# %%
text_pdf_loader = PyPDFLoader(file_path=ncert_book_path)

# %%
documents = text_pdf_loader.load()

# %%
for document in documents:
    print(document.page_content[:500])
# Out:
# Electricity
# 11CHAPTER
# E
# lectricity has an important place in modern society. It is a controllable
# and convenient form of energy for a variety of uses in homes, schools,
# hospitals, industries and so on. What constitutes electricity? How does
# it flow in an electric circuit? What are the factors that control or regulate
# the current through an electric circuit? In this Chapter, we shall attempt
# to answer such questions. We shall also discuss the heating effect of
# electric current and its application
# Science172
# If a net charge Q, flows across any cross-section of a conductor in
# time t, then the current I, through the cross-section is
# I Q
# t= (11.1)
# The SI unit of electric charge is coulomb (C), which is equivalent to
# the charge contained in nearly 6 × 10 18 electrons. (We know that an
# electron possesses a negative charge of 1.6 × 10 –19 C.) The electric
# current is expressed by a unit called ampere (A), named after the
# French scientist, Andre-Marie Ampere (1775–1836). One ampere is
# constituted
# Electricity 173
# 11.2 ELECTRIC POTENTIAL AND POTENTIAL DIFFERENCE11.2 ELECTRIC POTENTIAL AND POTENTIAL DIFFERENCE11.2 ELECTRIC POTENTIAL AND POTENTIAL DIFFERENCE11.2 ELECTRIC POTENTIAL AND POTENTIAL DIFFERENCE11.2 ELECTRIC POTENTIAL AND POTENTIAL DIFFERENCE
# What makes the electric charge to flow? Let us consider the analogy of
# flow of water. Charges do not flow in a copper wire by themselves, just as
# water in a perfectly horizontal tube does not flow. If one end of the tube
# is connected to a tank
# Science174
# W = VQ
# = 12 V × 2 C
# = 24 J.
# QUESTIONS
# ?
# 11.3 CIRCUIT DIAGRAM11.3 CIRCUIT DIAGRAM11.3 CIRCUIT DIAGRAM11.3 CIRCUIT DIAGRAM11.3 CIRCUIT DIAGRAM
# We know that an electric circuit, as shown in Fig. 11.1, comprises a cell
# (or a battery), a plug key, electrical component(s), and connecting wires.
# It is often convenient to draw a schematic diagram, in which different
# components of the circuit are represented by the symbols conveniently
# used. Conventional symbols  used to represent some of the
# Electricity 175
# 11.4 OHM’S LA11.4 OHM’S LA11.4 OHM’S LA11.4 OHM’S LA11.4 OHM’S LA W WW WW
# Is there a relationship between the potential difference across a conductor
# and the current through it? Let us explore with an Activity.
# Activity 11.1Activity 11.1Activity 11.1Activity 11.1Activity 11.1
# /square6Set up a circuit as shown in Fig. 11.2,
# consisting of a nichrome wire XY of length,
# say 0.5 m, an ammeter , a voltmeter and
# four cells of 1.5 V each. (Nichrome is an
# alloy of nickel, chromium, mangan
# Science176
# Figure 11.3Figure 11.3Figure 11.3Figure 11.3Figure 11.3
# V–I graph for a nichrome wire. A
# straight line plot shows that as the
# current through a wire increases, the
# potential difference across the wire
# increases linearly – this is Ohm’s law.
# Activity 11.2Activity 11.2Activity 11.2Activity 11.2Activity 11.2
# /square6Take a nichrome wire, a torch bulb, a 10 W bulb and an ammeter (0 – 5 A range), a plug
# key and some connecting wires.
# /square6Set up the circuit by connecting four dry cells
# Electricity 177
# In this Activity we observe that the current is different for different
# components. Why do they differ? Certain components offer an easy path
# for the flow of electric current while the others resist the flow. We know
# that motion of electrons in an electric circuit constitutes an electric
# current. The electrons, however, are not completely free to move within a
# conductor. They are restrained by the attraction of the atoms among
# which they move. Thus, motion of electrons through a
# Science178
# It is observed that the ammeter reading decreases to one-half when
# the length of the wire is doubled. The ammeter reading is increased when
# a thicker wire of the same material and of the same length is used in the
# circuit. A change in ammeter reading is observed when a wire of different
# material of the same length and the same area of cross-section is used.
# On applying Ohm’s law [Eqs. (11.5) – (11.7)], we observe that the
# resistance of the conductor depends (i) on its length, (ii) on
# Electricity 179
# have very low resistivity in the  range of 10–8 Ω m to  10–6 Ω m. They are
# good conductors of electricity. Insulators like rubber and glass have
# resistivity of the order of 10 12 to 10 17 Ω m. Both the resistance and
# resistivity of a material vary with temperature.
# Table 11.2 reveals that the resistivity of an alloy is generally higher
# than that of its constituent metals. Alloys do not oxidise (burn) readily
# at high temperatures. For this reason, they are commonly used in
# electri
# Science180
# Example 11.4
# The potential difference between the terminals of an electric heater
# is 60 V when it draws a current of 4 A from the source. What current
# will the heater draw if the potential difference is increased to 120 V?
# Solution
# We are given, potential difference V =  60 V, current I = 4 A.
# According to Ohm’s law,
# 60 V= = 154 A
# VR I= Ω .
# When the potential difference is increased to 120 V the current is
# given by
# current =
# 120 V= = 8 A15
# V
# R Ω .
# The current through the heater bec
# Electricity 181
# QUESTIONS
# ?
# 1. On what factors does the resistance of a
# conductor depend?
# 2. Will current flow more easily through a thick
# wire or a thin wire of the same material, when
# connected to the same source? Why?
# 3. Let the resistance of an electrical component
# remains constant while the potential difference
# across the two ends of the component
# decreases to half of its former value. What
# change will occur in the current through it?
# 4. Why are coils of electric toasters and electric
# irons
# Science182
# Figure 11.7Figure 11.7Figure 11.7Figure 11.7Figure 11.7  Resistors in parallel
# You will observe that the value of the current in the ammeter is the
# same, independent of its position in the electric circuit. It means that in
# a series combination of resistors the current is the same in every part of
# the circuit or the same current through each resistor.
# Activity 11.4Activity 11.4Activity 11.4Activity 11.4Activity 11.4
# /square6Join three resistors of different values in series. Connect t
# Electricity 183
# Activity 11.5Activity 11.5Activity 11.5Activity 11.5Activity 11.5
# /square6In Activity 11.4, insert a voltmeter across the ends X and Y of the
# series combination of three resistors, as shown in Fig. 11.6.
# /square6Plug the key in the circuit and note the voltmeter reading. It
# gives the potential difference across the series combination of
# resistors. Let it be V. Now measure the potential difference across
# the two terminals of the battery. Compare the two values.
# /square6Take out th
# Science184
# On applying Ohm’s law to the three resistors separately, we further
# have
# V1 = I R1 [11.13(a)]
# V2 = I R2 [11.13(b)]
# and V3 = I R3 [11.13(c)]
# From Eq. (11.11),
# I R = I R1 + I R2 + I R3
# or
# Rs = R1 +R2 + R3 (11.14)
# We can conclude that when several resistors are joined in series, the
# resistance of the combination R s equals the sum of their individual
# resistances, R1, R2, R3, and is thus greater than any individual resistance.
# Example 11.7
# An electric lamp, whose resistance is 20 Ω, and a
# Electricity 185
# Applying Ohm’s law to the electric lamp and conductor separately,
# we get potential difference across the electric lamp,
# V1 = 20 Ω × 0.25 A
# = 5 V;
# and,
# that across the conductor, V2  =  4 Ω × 0.25 A
#          =  1 V.
# Suppose that we like to replace the series combination of electric
# lamp and conductor by a single and equivalent resistor. Its resistance
# must be such that a potential difference of 6 V across the battery
# terminals will cause a current of 0.25 A in the circuit. The res
# Science186
# /square6Take out the plug from the key. Remove the ammeter and voltmeter from the circuit.
# Insert the ammeter in series with the resistor R1, as shown in Fig. 11.11. Note the ammeter
# reading, I1.
# Figure 11.11Figure 11.11Figure 11.11Figure 11.11Figure 11.11
# /square6Similarly, measure the currents through R2 and R3. Let these be I2 and I3, respectively.
# What is the relationship between I, I1, I2 and I3?
# It is observed that the total current I , is equal to the sum of the
# separate curren
# Electricity 187
# The current  I2, through R2 = V/ R2
# I2 = 12 V/10 Ω = 1.2 A.
# The current  I3, through R3 = V/R3
# I3 = 12 V/30 Ω = 0.4 A.
# The total current in the circuit,
# I =  I1 + I2 + I3
# = (2.4 + 1.2 + 0.4) A
# = 4 A
# The total resistance Rp, is given by [Eq. (11.18)]
# 1 1 1 1 1
# 5 10 30 3pR = + + =
# Thus, Rp = 3 Ω.
# Example 11.9
# If in Fig. 11.12, R1 = 10 Ω, R2 = 40 Ω, R3 = 30 Ω, R4 = 20 Ω, R5 = 60 Ω,
# and a 12 V battery is connected to the arrangement. Calculate
# (a) the total resistance in the circuit,
# Science188
# 11.7 HEA 11.7 HEA11.7 HEA 11.7 HEA11.7 HEA TING EFFECT OF ELECTRIC CURRENTTING EFFECT OF ELECTRIC CURRENTTING EFFECT OF ELECTRIC CURRENTTING EFFECT OF ELECTRIC CURRENTTING EFFECT OF ELECTRIC CURRENT
# We know that a battery or a cell is a sour ce of electrical energy. The
# chemical reaction within the cell generates the potential difference between
# its two terminals that sets the electrons in motion to flow the current
# through a resistor or a system of resistors connected to the battery.
# Electricity 189
# Applying Ohm’s law [Eq. (11.5)], we get
# H = I2 Rt (11.21)
# This is known as Joule’s law of heating. The
# law implies that heat produced in a resistor is
# (i) directly proportional to the square of current
# for a given resistance, (ii) directly proportional to
# resistance for a given current, and (iii) directly
# proportional to the time for which the current flows
# through the resistor. In practical situations, when
# an electric appliance is connected to a known
# voltage source, Eq. (11.21
# Science190
# 11.7.1 Practical Applications of Heating Effect of
# Electric Current
# The generation of heat in a conductor is an inevitable consequence of
# electric current. In many cases, it is undesirable as it converts useful
# electrical energy into heat. In electric circuits, the unavoidable heating
# can increase the temperature of the components and alter their properties.
# However, heating effect of electric current has many useful applications.
# The electric laundry iron, electric toaster, electric
# Electricity 191
# 11.8 ELECTRIC POWER11.8 ELECTRIC POWER11.8 ELECTRIC POWER11.8 ELECTRIC POWER11.8 ELECTRIC POWER
# You have studied in your earlier Class that the rate of doing work is
# power. This is also the rate of consumption of energy.
# Equation (11.21) gives the rate at which electric energy is dissipated
# or consumed in an electric circuit. This is also termed as electric power.
# The power P is given by
# P  =  VI
# Or P  =  I2R = V2/R (11.22)
# The SI unit of electric power is watt (W). It is the pow
# Science192
# QUESTIONS
# ?
# 1. What determines the rate at which energy is delivered by a current?
# 2. An electric motor takes 5 A from a 220 V line. Determine the power of
# the motor and the energy consumed in 2 h.
# What you have learnt
# /square6A stream of electrons moving through a conductor constitutes an electric current.
# Conventionally, the direction of current is taken opposite to the direction of flow of
# electrons.
# /square6The SI unit of electric current is ampere.
# /square6To set the electrons in
# Electricity 193
# EXERCISES
# 1. A piece of wire of resistance R  is cut into five equal parts. These parts are then
# connected in parallel. If the equivalent resistance of this combination is R′, then the
# ratio R/R′ is  –
# (a) 1/25 (b) 1/5 (c) 5 (d) 25
# 2. Which of the following terms does not represent electrical power in a circuit?
# (a) I2R (b) IR2 (c) VI (d) V2/R
# 3. An electric bulb is rated 220 V and 100 W . When it is operated on 110 V , the
# power consumed will be –
# (a) 100 W (b) 75 W (c) 50 W (d)
# Science194 194194 194194
# 15. Two lamps, one rated 100 W at 220 V, and the other 60 W at 220 V, are connected
# in parallel to electric mains supply. What current is drawn from the line if the supply
# voltage is 220 V?
# 16. Which uses more energy, a 250 W TV set in 1 hr, or a 1200 W toaster in 10 minutes?
# 17. An electric heater of resistance 44 Ω draws 5 A from the service mains for 2 hours.
# Calculate the rate at which heat is developed in the heater.
# 18. Explain the following.
# (a) Why is the tungste

# %%
# Lets look at page 1

page1 = documents[0]

# %%
page1.metadata
# Out:
# {'producer': 'GPL Ghostscript 8.15',
#  'creator': 'PageMaker 7.0',
#  'creationdate': '2022-08-17T15:09:57+00:00',
#  'author': 'admin',
#  'moddate': '2025-04-04T12:10:22+05:30',
#  'title': 'CHAP 11.pmd',
#  'source': 'data/science-chapter-11.pdf',
#  'total_pages': 24,
#  'page': 0,
#  'page_label': '1'}

# %%
print(page1.page_content)
# Out:
# Electricity
# 11CHAPTER
# E
# lectricity has an important place in modern society. It is a controllable
# and convenient form of energy for a variety of uses in homes, schools,
# hospitals, industries and so on. What constitutes electricity? How does
# it flow in an electric circuit? What are the factors that control or regulate
# the current through an electric circuit? In this Chapter, we shall attempt
# to answer such questions. We shall also discuss the heating effect of
# electric current and its applications.
# 11.1 ELECTRIC CURRENT AND CIRCUIT11.1 ELECTRIC CURRENT AND CIRCUIT11.1 ELECTRIC CURRENT AND CIRCUIT11.1 ELECTRIC CURRENT AND CIRCUIT11.1 ELECTRIC CURRENT AND CIRCUIT
# We are familiar with air current and water current. We know that flowing
# water constitute water current in rivers. Similarly, if the electric charge
# flows through a conductor (for example, through a metallic wire), we
# say that there is an electric curr ent in the conductor. In a tor ch, we
# know that the cells (or a battery, when placed in proper order) provide
# flow of charges or an electric current through the torch bulb to glow. We
# have also seen that the torch gives light only when its switch is on. What
# does a switch do? A switch makes a conducting link between the cell and
# the bulb. A continuous and closed path of an electric current is called an
# electric circuit. Now, if the circuit is broken anywhere (or the switch of the
# torch is turned off ), the current stops flowing and the bulb does not glow.
# How do we express electric current? Electric current is expressed by
# the amount of charge flowing through a particular area in unit time. In
# other words, it is the rate of flow of electric charges. In circuits using
# metallic wires, electrons constitute the flow of charges. However, electrons
# were not known at the time when the phenomenon of electricity was first
# observed. So, electric current was considered to be the flow of positive
# charges and the direction of flow of positive charges was taken to be the
# direction of electric current. Conventionally, in an electric circuit the
# direction of electric current is taken as opposite to the direction of the
# flow of electrons, which are negative charges.
# Reprint 2025-26

# %%
text_images_document_loader = PyPDFLoader(
file_path="data/science-chapter-11.pdf", 
extract_images=True)

# %%
documents = text_images_document_loader.load()
page1 = documents[0]

# %%
page1.metadata
# Out:
# {'producer': 'GPL Ghostscript 8.15',
#  'creator': 'PageMaker 7.0',
#  'creationdate': '2022-08-17T15:09:57+00:00',
#  'author': 'admin',
#  'moddate': '2025-04-04T12:10:22+05:30',
#  'title': 'CHAP 11.pmd',
#  'source': 'data/science-chapter-11.pdf',
#  'total_pages': 24,
#  'page': 0,
#  'page_label': '1'}

# %%
print(page1.page_content)
# Out:
# Electricity
# 11CHAPTER
# E
# lectricity has an important place in modern society. It is a controllable
# and convenient form of energy for a variety of uses in homes, schools,
# hospitals, industries and so on. What constitutes electricity? How does
# it flow in an electric circuit? What are the factors that control or regulate
# the current through an electric circuit? In this Chapter, we shall attempt
# to answer such questions. We shall also discuss the heating effect of
# electric current and its applications.
# 11.1 ELECTRIC CURRENT AND CIRCUIT11.1 ELECTRIC CURRENT AND CIRCUIT11.1 ELECTRIC CURRENT AND CIRCUIT11.1 ELECTRIC CURRENT AND CIRCUIT11.1 ELECTRIC CURRENT AND CIRCUIT
# We are familiar with air current and water current. We know that flowing
# water constitute water current in rivers. Similarly, if the electric charge
# flows through a conductor (for example, through a metallic wire), we
# say that there is an electric curr ent in the conductor. In a tor ch, we
# know that the cells (or a battery, when placed in proper order) provide
# flow of charges or an electric current through the torch bulb to glow. We
# have also seen that the torch gives light only when its switch is on. What
# does a switch do? A switch makes a conducting link between the cell and
# the bulb. A continuous and closed path of an electric current is called an
# electric circuit. Now, if the circuit is broken anywhere (or the switch of the
# torch is turned off ), the current stops flowing and the bulb does not glow.
# How do we express electric current? Electric current is expressed by
# the amount of charge flowing through a particular area in unit time. In
# other words, it is the rate of flow of electric charges. In circuits using
# metallic wires, electrons constitute the flow of charges. However, electrons
# were not known at the time when the phenomenon of electricity was first
# observed. So, electric current was considered to be the flow of positive
# charges and the direction of flow of positive charges was taken to be the
# direction of electric current. Conventionally, in an electric circuit the
# direction of electric current is taken as opposite to the direction of the
# flow of electrons, which are negative charges.
# Reprint 2025-26

# %%
len(documents)
# Out:
# 24

# %%
for document in documents:
    print(document.metadata)
# Out:
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 0, 'page_label': '1'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 1, 'page_label': '2'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 2, 'page_label': '3'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 3, 'page_label': '4'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 4, 'page_label': '5'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 5, 'page_label': '6'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 6, 'page_label': '7'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 7, 'page_label': '8'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 8, 'page_label': '9'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 9, 'page_label': '10'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 10, 'page_label': '11'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 11, 'page_label': '12'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 12, 'page_label': '13'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 13, 'page_label': '14'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 14, 'page_label': '15'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 15, 'page_label': '16'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 16, 'page_label': '17'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 17, 'page_label': '18'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 18, 'page_label': '19'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 19, 'page_label': '20'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 20, 'page_label': '21'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 21, 'page_label': '22'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 22, 'page_label': '23'}
# {'producer': 'GPL Ghostscript 8.15', 'creator': 'PageMaker 7.0', 'creationdate': '2022-08-17T15:09:57+00:00', 'author': 'admin', 'moddate': '2025-04-04T12:10:22+05:30', 'title': 'CHAP 11.pmd', 'source': 'data/science-chapter-11.pdf', 'total_pages': 24, 'page': 23, 'page_label': '24'}

# %%
from pypdf import PdfReader

def extract_images_from_pdf(pdf_path, output_folder="."):
    """
    Extracts all images from a given PDF file and saves them to an output folder.
    """
    reader = PdfReader(pdf_path)
    print(f"Opened PDF: {pdf_path}")
    image_count = 0

    for page_num, page in enumerate(reader.pages):
        print(f"Processing page {page_num + 1}...")
        for i, image_file_object in enumerate(page.images):
            # Generate a unique file name
            file_name = f"{output_folder}/page{page_num+1}-image{i+1}-{image_file_object.name}"
            
            try:
                # Save the image data
                with open(file_name, "wb") as f:
                    f.write(image_file_object.data)
                print(f"  Saved image: {file_name}")
                image_count += 1
            except Exception as e:
                print(f"  Error saving image {file_name}: {e}")

    print(f"Extraction complete. Total images saved: {image_count}")

# Example usage:
# Replace "example.pdf" with the path to your PDF file
extract_images_from_pdf(ncert_book_path, output_folder="extracted_images")
# Out:
# Opened PDF: data/science-chapter-11.pdf
# Processing page 1...
#   Saved image: extracted_images/page1-image1-Im0.png
#   Saved image: extracted_images/page1-image2-Im0.png
#   Saved image: extracted_images/page1-image3-Im0.png
# Processing page 2...
#   Saved image: extracted_images/page2-image1-Im0.png
#   Saved image: extracted_images/page2-image2-Im0.png
# Processing page 3...
#   Saved image: extracted_images/page3-image1-Im0.png
#   Saved image: extracted_images/page3-image2-Im0.png
# Processing page 4...
#   Saved image: extracted_images/page4-image1-Im0.png
#   Saved image: extracted_images/page4-image2-Im0.png
# Processing page 5...
#   Saved image: extracted_images/page5-image1-Im0.png
#   Saved image: extracted_images/page5-image2-Im0.png
# Processing page 6...
#   Saved image: extracted_images/page6-image1-Im0.png
#   Saved image: extracted_images/page6-image2-Im0.png
# Processing page 7...
#   Saved image: extracted_images/page7-image1-Im0.png
#   Saved image: extracted_images/page7-image2-Im0.png
# Processing page 8...
#   Saved image: extracted_images/page8-image1-Im0.png
#   Saved image: extracted_images/page8-image2-Im0.png
# Processing page 9...
#   Saved image: extracted_images/page9-image1-Im0.png
#   Saved image: extracted_images/page9-image2-Im0.png
# Processing page 10...
#   Saved image: extracted_images/page10-image1-Im0.png
#   Saved image: extracted_images/page10-image2-Im0.png
# Processing page 11...
#   Saved image: extracted_images/page11-image1-Im0.png
#   Saved image: extracted_images/page11-image2-Im0.png
# Processing page 12...
#   Saved image: extracted_images/page12-image1-Im0.png
#   Saved image: extracted_images/page12-image2-Im0.png
# Processing page 13...
#   Saved image: extracted_images/page13-image1-Im0.png
#   Saved image: extracted_images/page13-image2-Im0.png
# Processing page 14...
#   Saved image: extracted_images/page14-image1-Im0.png
#   Saved image: extracted_images/page14-image2-Im0.png
# Processing page 15...
#   Saved image: extracted_images/page15-image1-Im0.png
#   Saved image: extracted_images/page15-image2-Im0.png
# Processing page 16...
#   Saved image: extracted_images/page16-image1-Im0.png
#   Saved image: extracted_images/page16-image2-Im0.png
# Processing page 17...
#   Saved image: extracted_images/page17-image1-Im0.png
#   Saved image: extracted_images/page17-image2-Im0.png
# Processing page 18...
#   Saved image: extracted_images/page18-image1-Im0.png
#   Saved image: extracted_images/page18-image2-Im0.png
# Processing page 19...
#   Saved image: extracted_images/page19-image1-Im0.png
#   Saved image: extracted_images/page19-image2-Im0.png
# Processing page 20...
#   Saved image: extracted_images/page20-image1-Im0.png
#   Saved image: extracted_images/page20-image2-Im0.png
# Processing page 21...
#   Saved image: extracted_images/page21-image1-Im0.png
#   Saved image: extracted_images/page21-image2-Im0.png
# Processing page 22...
#   Saved image: extracted_images/page22-image1-Im0.png
#   Saved image: extracted_images/page22-image2-Im0.png
# Processing page 23...
#   Saved image: extracted_images/page23-image1-Im0.png
#   Saved image: extracted_images/page23-image2-Im0.png
# Processing page 24...
#   Saved image: extracted_images/page24-image1-Im0.png
#   Saved image: extracted_images/page24-image2-Im0.png
# Extraction complete. Total images saved: 49

# %%
panchatantra_path = "data/panchtantra.pdf"
extract_images_from_pdf(panchatantra_path, output_folder="panchatantra_images")
# Out:
# Opened PDF: data/panchtantra.pdf
# Processing page 1...
#   Saved image: panchatantra_images/page1-image1-R13.jpg
# Processing page 2...
#   Saved image: panchatantra_images/page2-image1-R24.jpg
#   Saved image: panchatantra_images/page2-image2-R23.jpg
# Processing page 3...
#   Saved image: panchatantra_images/page3-image1-R31.jpg
#   Saved image: panchatantra_images/page3-image2-R30.jpg
# Processing page 4...
#   Saved image: panchatantra_images/page4-image1-R39.jpg
#   Saved image: panchatantra_images/page4-image2-R38.jpg
#   Saved image: panchatantra_images/page4-image3-R37.jpg
# Processing page 5...
#   Saved image: panchatantra_images/page5-image1-R47.jpg
#   Saved image: panchatantra_images/page5-image2-~0~.png
#   Saved image: panchatantra_images/page5-image3-~1~.png
#   Saved image: panchatantra_images/page5-image4-~2~.png
#   Saved image: panchatantra_images/page5-image5-~3~.png
#   Saved image: panchatantra_images/page5-image6-~4~.png
#   Saved image: panchatantra_images/page5-image7-~5~.png
#   Saved image: panchatantra_images/page5-image8-~6~.png
#   Saved image: panchatantra_images/page5-image9-~7~.png
#   Saved image: panchatantra_images/page5-image10-~8~.png
#   Saved image: panchatantra_images/page5-image11-~9~.png
#   Saved image: panchatantra_images/page5-image12-~10~.png
#   Saved image: panchatantra_images/page5-image13-~11~.png
#   Saved image: panchatantra_images/page5-image14-~12~.png
#   Saved image: panchatantra_images/page5-image15-~13~.png
#   Saved image: panchatantra_images/page5-image16-~14~.png
#   Saved image: panchatantra_images/page5-image17-~15~.png
#   Saved image: panchatantra_images/page5-image18-~16~.png
#   Saved image: panchatantra_images/page5-image19-~17~.png
#   Saved image: panchatantra_images/page5-image20-~18~.png
#   Saved image: panchatantra_images/page5-image21-~19~.png
#   Saved image: panchatantra_images/page5-image22-~20~.png
#   Saved image: panchatantra_images/page5-image23-~21~.png
#   Saved image: panchatantra_images/page5-image24-~22~.png
#   Saved image: panchatantra_images/page5-image25-~23~.png
#   Saved image: panchatantra_images/page5-image26-~24~.png
#   Saved image: panchatantra_images/page5-image27-~25~.png
#   Saved image: panchatantra_images/page5-image28-~26~.png
#   Saved image: panchatantra_images/page5-image29-~27~.png
#   Saved image: panchatantra_images/page5-image30-~28~.png
#   Saved image: panchatantra_images/page5-image31-~29~.png
#   Saved image: panchatantra_images/page5-image32-~30~.png
#   Saved image: panchatantra_images/page5-image33-~31~.png
#   Saved image: panchatantra_images/page5-image34-~32~.png
#   Saved image: panchatantra_images/page5-image35-~33~.png
#   Saved image: panchatantra_images/page5-image36-~34~.png
#   Saved image: panchatantra_images/page5-image37-~35~.png
#   Saved image: panchatantra_images/page5-image38-~36~.png
#   Saved image: panchatantra_images/page5-image39-~37~.png
#   Saved image: panchatantra_images/page5-image40-~38~.png
#   Saved image: panchatantra_images/page5-image41-~39~.png
#   Saved image: panchatantra_images/page5-image42-~40~.png
#   Saved image: panchatantra_images/page5-image43-~41~.png
#   Saved image: panchatantra_images/page5-image44-~42~.png
#   Saved image: panchatantra_images/page5-image45-~43~.png
#   Saved image: panchatantra_images/page5-image46-~44~.png
#   Saved image: panchatantra_images/page5-image47-~45~.png
#   Saved image: panchatantra_images/page5-image48-~46~.png
#   Saved image: panchatantra_images/page5-image49-~47~.png
#   Saved image: panchatantra_images/page5-image50-~48~.png
#   Saved image: panchatantra_images/page5-image51-~49~.png
#   Saved image: panchatantra_images/page5-image52-~50~.png
#   Saved image: panchatantra_images/page5-image53-~51~.png
#   Saved image: panchatantra_images/page5-image54-~52~.png
#   Saved image: panchatantra_images/page5-image55-~53~.png
#   Saved image: panchatantra_images/page5-image56-~54~.png
#   Saved image: panchatantra_images/page5-image57-~55~.png
#   Saved image: panchatantra_images/page5-image58-~56~.png
#   Saved image: panchatantra_images/page5-image59-~57~.png
#   Saved image: panchatantra_images/page5-image60-~58~.png
#   Saved image: panchatantra_images/page5-image61-~59~.png
#   Saved image: panchatantra_images/page5-image62-~60~.png
#   Saved image: panchatantra_images/page5-image63-~61~.png
#   Saved image: panchatantra_images/page5-image64-~62~.png
#   Saved image: panchatantra_images/page5-image65-~63~.png
#   Saved image: panchatantra_images/page5-image66-~64~.png
#   Saved image: panchatantra_images/page5-image67-~65~.png
#   Saved image: panchatantra_images/page5-image68-~66~.png
#   Saved image: panchatantra_images/page5-image69-~67~.png
#   Saved image: panchatantra_images/page5-image70-~68~.png
#   Saved image: panchatantra_images/page5-image71-~69~.png
#   Saved image: panchatantra_images/page5-image72-~70~.png
#   Saved image: panchatantra_images/page5-image73-~71~.png
#   Saved image: panchatantra_images/page5-image74-~72~.png
#   Saved image: panchatantra_images/page5-image75-~73~.png
#   Saved image: panchatantra_images/page5-image76-~74~.png
#   Saved image: panchatantra_images/page5-image77-~75~.png
#   Saved image: panchatantra_images/page5-image78-~76~.png
#   Saved image: panchatantra_images/page5-image79-~77~.png
#   Saved image: panchatantra_images/page5-image80-~78~.png
#   Saved image: panchatantra_images/page5-image81-~79~.png
#   Saved image: panchatantra_images/page5-image82-~80~.png
#   Saved image: panchatantra_images/page5-image83-~81~.png
#   Saved image: panchatantra_images/page5-image84-~82~.png
#   Saved image: panchatantra_images/page5-image85-~83~.png
#   Saved image: panchatantra_images/page5-image86-~84~.png
#   Saved image: panchatantra_images/page5-image87-~85~.png
#   Saved image: panchatantra_images/page5-image88-~86~.png
#   Saved image: panchatantra_images/page5-image89-~87~.png
#   Saved image: panchatantra_images/page5-image90-~88~.png
#   Saved image: panchatantra_images/page5-image91-~89~.png
#   Saved image: panchatantra_images/page5-image92-~90~.png
#   Saved image: panchatantra_images/page5-image93-~91~.png
# Processing page 6...
#   Saved image: panchatantra_images/page6-image1-R53.jpg
# Processing page 7...
#   Saved image: panchatantra_images/page7-image1-R59.jpg
#   Saved image: panchatantra_images/page7-image2-~0~.png
#   Saved image: panchatantra_images/page7-image3-~1~.png
#   Saved image: panchatantra_images/page7-image4-~2~.png
#   Saved image: panchatantra_images/page7-image5-~3~.png
#   Saved image: panchatantra_images/page7-image6-~4~.png
#   Saved image: panchatantra_images/page7-image7-~5~.png
#   Saved image: panchatantra_images/page7-image8-~6~.png
#   Saved image: panchatantra_images/page7-image9-~7~.png
#   Saved image: panchatantra_images/page7-image10-~8~.png
#   Saved image: panchatantra_images/page7-image11-~9~.png
#   Saved image: panchatantra_images/page7-image12-~10~.png
#   Saved image: panchatantra_images/page7-image13-~11~.png
#   Saved image: panchatantra_images/page7-image14-~12~.png
#   Saved image: panchatantra_images/page7-image15-~13~.png
#   Saved image: panchatantra_images/page7-image16-~14~.png
#   Saved image: panchatantra_images/page7-image17-~15~.png
#   Saved image: panchatantra_images/page7-image18-~16~.png
#   Saved image: panchatantra_images/page7-image19-~17~.png
#   Saved image: panchatantra_images/page7-image20-~18~.png
#   Saved image: panchatantra_images/page7-image21-~19~.png
#   Saved image: panchatantra_images/page7-image22-~20~.png
#   Saved image: panchatantra_images/page7-image23-~21~.png
#   Saved image: panchatantra_images/page7-image24-~22~.png
#   Saved image: panchatantra_images/page7-image25-~23~.png
#   Saved image: panchatantra_images/page7-image26-~24~.png
#   Saved image: panchatantra_images/page7-image27-~25~.png
#   Saved image: panchatantra_images/page7-image28-~26~.png
#   Saved image: panchatantra_images/page7-image29-~27~.png
#   Saved image: panchatantra_images/page7-image30-~28~.png
#   Saved image: panchatantra_images/page7-image31-~29~.png
#   Saved image: panchatantra_images/page7-image32-~30~.png
#   Saved image: panchatantra_images/page7-image33-~31~.png
#   Saved image: panchatantra_images/page7-image34-~32~.png
#   Saved image: panchatantra_images/page7-image35-~33~.png
#   Saved image: panchatantra_images/page7-image36-~34~.png
#   Saved image: panchatantra_images/page7-image37-~35~.png
#   Saved image: panchatantra_images/page7-image38-~36~.png
#   Saved image: panchatantra_images/page7-image39-~37~.png
#   Saved image: panchatantra_images/page7-image40-~38~.png
#   Saved image: panchatantra_images/page7-image41-~39~.png
#   Saved image: panchatantra_images/page7-image42-~40~.png
#   Saved image: panchatantra_images/page7-image43-~41~.png
#   Saved image: panchatantra_images/page7-image44-~42~.png
#   Saved image: panchatantra_images/page7-image45-~43~.png
#   Saved image: panchatantra_images/page7-image46-~44~.png
#   Saved image: panchatantra_images/page7-image47-~45~.png
#   Saved image: panchatantra_images/page7-image48-~46~.png
#   Saved image: panchatantra_images/page7-image49-~47~.png
#   Saved image: panchatantra_images/page7-image50-~48~.png
#   Saved image: panchatantra_images/page7-image51-~49~.png
#   Saved image: panchatantra_images/page7-image52-~50~.png
#   Saved image: panchatantra_images/page7-image53-~51~.png
#   Saved image: panchatantra_images/page7-image54-~52~.png
#   Saved image: panchatantra_images/page7-image55-~53~.png
#   Saved image: panchatantra_images/page7-image56-~54~.png
#   Saved image: panchatantra_images/page7-image57-~55~.png
#   Saved image: panchatantra_images/page7-image58-~56~.png
#   Saved image: panchatantra_images/page7-image59-~57~.png
#   Saved image: panchatantra_images/page7-image60-~58~.png
#   Saved image: panchatantra_images/page7-image61-~59~.png
#   Saved image: panchatantra_images/page7-image62-~60~.png
#   Saved image: panchatantra_images/page7-image63-~61~.png
#   Saved image: panchatantra_images/page7-image64-~62~.png
#   Saved image: panchatantra_images/page7-image65-~63~.png
#   Saved image: panchatantra_images/page7-image66-~64~.png
#   Saved image: panchatantra_images/page7-image67-~65~.png
#   Saved image: panchatantra_images/page7-image68-~66~.png
# Processing page 8...
#   Saved image: panchatantra_images/page8-image1-R65.jpg
# Processing page 9...
#   Saved image: panchatantra_images/page9-image1-R71.jpg
# Processing page 10...
#   Saved image: panchatantra_images/page10-image1-R77.jpg
# Processing page 11...
# Processing page 12...
# Processing page 13...
#   Saved image: panchatantra_images/page13-image1-R92.jpg
#   Saved image: panchatantra_images/page13-image2-R91.jpg
# Processing page 14...
#   Saved image: panchatantra_images/page14-image1-R99.jpg
#   Saved image: panchatantra_images/page14-image2-R98.jpg
# Processing page 15...
#   Saved image: panchatantra_images/page15-image1-R106.jpg
#   Saved image: panchatantra_images/page15-image2-R105.jpg
# Processing page 16...
#   Saved image: panchatantra_images/page16-image1-R114.jpg
#   Saved image: panchatantra_images/page16-image2-R113.jpg
#   Saved image: panchatantra_images/page16-image3-R112.jpg
# Processing page 17...
#   Saved image: panchatantra_images/page17-image1-R122.jpg
#   Saved image: panchatantra_images/page17-image2-R121.jpg
#   Saved image: panchatantra_images/page17-image3-R120.jpg
# Processing page 18...
#   Saved image: panchatantra_images/page18-image1-R130.jpg
#   Saved image: panchatantra_images/page18-image2-R129.jpg
#   Saved image: panchatantra_images/page18-image3-R128.jpg
# Processing page 19...
#   Saved image: panchatantra_images/page19-image1-R137.jpg
#   Saved image: panchatantra_images/page19-image2-R136.jpg
# Processing page 20...
#   Saved image: panchatantra_images/page20-image1-R144.jpg
#   Saved image: panchatantra_images/page20-image2-R143.jpg
# Processing page 21...
#   Saved image: panchatantra_images/page21-image1-R151.jpg
#   Saved image: panchatantra_images/page21-image2-R150.jpg
# Processing page 22...
#   Saved image: panchatantra_images/page22-image1-R158.jpg
#   Saved image: panchatantra_images/page22-image2-R157.jpg
# Processing page 23...
#   Saved image: panchatantra_images/page23-image1-R164.jpg
# Extraction complete. Total images saved: 197

# %%
#Lets  see the text
panchatantra_loader = PyPDFLoader(file_path=panchatantra_path)
documents = panchatantra_loader.load()

# %%
documents[0].metadata
# Out:
# {'producer': 'AFPL Ghostscript 8.53',
#  'creator': 'PScript5.dll Version 5.2.2',
#  'creationdate': 'D:20070709165412',
#  'moddate': 'D:20070709165412',
#  'title': 'Microsoft Word - panchtantra.doc',
#  'author': 'Administrator',
#  'source': 'data/panchtantra.pdf',
#  'total_pages': 23,
#  'page': 0,
#  'page_label': '1'}

# %%
print(documents[0].page_content)
# Out:
# Purna Vidya 1
# Panchatantra Stories
#
#
#
#
#
#
# Kumud Singhal

# %%
print(documents[1].page_content)
# Out:
# Purna Vidya 2
#
# Story of PancnTantra
